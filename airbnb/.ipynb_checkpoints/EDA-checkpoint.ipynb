# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import style
import warnings

# style.use('fivethirtyeight')
style.use('seaborn')
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('data/train_users_2.csv')
test_df = pd.read_csv('data/test_users.csv')
sessions = pd.read_csv('data/sessions.csv')
countries = pd.read_csv('data/countries.csv')
age_gender = pd.read_csv('data/age_gender_bkts.csv')

# %% [markdown]
# ## Basic Infos

# %%
# for df in [train_df, sessions, countries, age_gender]:
#     print(df.info())
#     print('-'*50)

# %%
# for df in [train_df, sessions, countries, age_gender]:
#     print(df.describe())
#     print('-'*50)

# %% [markdown]
# ## EDA
# 1. train_df
# 2. age_gender

# %%
train_df.head(3)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US

# %% [markdown]
# ### 確認target 是否有data imbalance問題
# 1. 6成NDF，3成US
# 2. Evaluation metrics：NDCG
# 3. data imbalance 問題

# %%
print('目的地占比 %')
(train_df.iloc[:, -1].value_counts()/len(train_df))*100
# Out:
# 目的地占比 %
# NDF      58.347349
# US       29.222632
# other     4.728954
# FR        2.353233
# IT        1.328174
# GB        1.088774
# ES        1.053638
# CA        0.669006
# DE        0.497070
# NL        0.356991
# AU        0.252517
# PT        0.101663
# Name: country_destination, dtype: float64

# %%
sessions.head(3)
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0

# %%
countries.head(3)
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61

# %%
age_gender
# Out:
#     age_bucket country_destination  gender  population_in_thousands    year
# 0         100+                  AU    male                      1.0  2015.0
# 1        95-99                  AU    male                      9.0  2015.0
# 2        90-94                  AU    male                     47.0  2015.0
# 3        85-89                  AU    male                    118.0  2015.0
# 4        80-84                  AU    male                    199.0  2015.0
# ..         ...                 ...     ...                      ...     ...
# 415      95-99                  US    male                    115.0  2015.0
# 416      90-94                  US    male                    541.0  2015.0
# 417      15-19                  US  female                  10570.0  2015.0
# 418      85-89                  US    male                   1441.0  2015.0
# 419      80-84                  US    male                   2442.0  2015.0
#
# [420 rows x 5 columns]

# %% [markdown]
# ### date_first_booking 缺值 -> NDF, 沒缺 -> 沒有NDF

# %%
train_df[train_df['date_first_booking'].isnull()]['country_destination'].value_counts()
# Out:
# NDF    124543
# Name: country_destination, dtype: int64

# %%
train_df[train_df['date_first_booking'].notnull()]['country_destination'].value_counts()
# Out:
# US       62376
# other    10094
# FR        5023
# IT        2835
# GB        2324
# ES        2249
# CA        1428
# DE        1061
# NL         762
# AU         539
# PT         217
# Name: country_destination, dtype: int64

# %%
new_df = train_df[train_df['date_first_booking'].notnull()]

# %% [markdown]
# ## 類別 vs 類別
# The df.plot() function returns a matplotlib.axes.AxesSubplot object

# %%
cat_cols = train_df.select_dtypes(include='object').columns[3:-1]
print(f'column length: {len(cat_cols)}')
# Out:
# column length: 9

# %%
# fig, axes = plt.subplots(nrows=3, ncols=3, figsize= (20,12))

# for i, col in enumerate(cat_cols):
#     df = (train_df.groupby(['country_destination'])[col].value_counts()/train_df.groupby(['country_destination']).size()).unstack()
#     df.plot(kind= 'bar', ax= axes[int(i/3), (i%3)])
    
# plt.tight_layout()
# plt.show()

# %%
# for i, col in enumerate(cat_cols):
#     plt.figure(figsize=(20,20))
#     ax = (train_df.groupby(['country_destination'])[col].value_counts()/train_df.groupby(['country_destination']).size()).unstack().plot(kind= 'bar')
#     ax.set_xlabel('target destination')
#     ax.set_ylabel('percentage')
#     ax.set_title('hist')
#     plt.show()

# %% [markdown]
# ### 語言和target有關係

# %%
(new_df.groupby(['language'])['country_destination'].value_counts()*100/new_df.groupby(['language']).size()).round(1).unstack()
# Out:
# country_destination   AU   CA   DE    ES    FR    GB    IT    NL   PT     US  \
# language
# ca                   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  100.0
# cs                   NaN  NaN  NaN  11.1   NaN   NaN   NaN   NaN  NaN   66.7
# da                   NaN  NaN  NaN  10.5   NaN   NaN   5.3   NaN  NaN   73.7
# de                   1.1  0.4  8.9   2.6   3.7   1.9   2.2   0.7  0.4   71.5
# el                   NaN  NaN  NaN  33.3  16.7   NaN   NaN   NaN  NaN   33.3
# en                   0.6  1.6  1.2   2.5   5.6   2.6   3.2   0.9  0.2   70.2
# es                   NaN  NaN  2.2   7.3   6.5   2.2   3.3   0.4  0.7   60.4
# fi                   NaN  NaN  NaN   NaN  14.3   NaN   NaN   NaN  NaN   71.4
# fr                   0.5  1.8  2.0   2.8  17.3   3.0   2.8   1.0  0.5   63.7
# hu                   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN   75.0
# is                   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN   50.0
# it                   NaN  1.0  1.9   5.8   2.9   3.8  18.3   1.9  NaN   57.7
# ja                   NaN  2.4  NaN   1.2   4.8   2.4   2.4   NaN  NaN   73.8
# ko                   0.4  0.8  NaN   0.8   5.0   1.2   3.7   0.8  NaN   63.1
# nl                   NaN  NaN  5.7   NaN   8.6   NaN   2.9  11.4  NaN   54.3
# no                   NaN  NaN  NaN   NaN   NaN  15.4   NaN   NaN  NaN   76.9
# pl                   NaN  NaN  NaN  15.4   7.7   NaN   7.7   NaN  7.7   46.2
# pt                   NaN  NaN  NaN   1.6   NaN   NaN   NaN   1.6  1.6   66.1
# ru                   NaN  0.9  0.9   5.5   4.5   0.9   6.4   NaN  NaN   68.2
# sv                   NaN  NaN  NaN   4.5   NaN   NaN   NaN   4.5  NaN   75.0
# th                   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN   75.0
# tr                   NaN  NaN  NaN   NaN   5.0   NaN   5.0   NaN  NaN   70.0
# zh                   0.4  0.4  0.4   0.6   2.5   1.0   1.0   NaN  NaN   78.7
#
# country_destination  other
# language
# ca                     NaN
# cs                    22.2
# da                    10.5
# de                     6.7
# el                    16.7
# en                    11.3
# es                    17.1
# fi                    14.3
# fr                     4.8
# hu                    25.0
# is                    50.0
# it                     6.7
# ja                    13.1
# ko                    24.1
# nl                    17.1
# no                     7.7
# pl                    15.4
# pt                    29.0
# ru                    12.7
# sv                    15.9
# th                    25.0
# tr                    20.0
# zh                    15.2

# %% [markdown]
# ### 性別對target影響差異不大

# %%
(new_df.groupby(['gender'])['country_destination'].value_counts()*100/new_df.groupby(['gender']).size()).round(1).unstack()
# Out:
# country_destination   AU   CA   DE   ES   FR   GB   IT   NL   PT    US  other
# gender
# -unknown-            0.5  1.7  1.0  2.5  5.9  2.6  3.6  0.8  0.2  69.3   12.0
# FEMALE               0.6  1.4  1.1  2.7  6.1  2.8  3.4  0.8  0.2  70.9    9.9
# MALE                 0.7  1.7  1.5  2.4  4.8  2.5  2.5  1.0  0.2  70.2   12.4
# OTHER                0.6  2.8  1.7  2.3  7.4  1.7  2.8  1.7  0.6  65.9   12.5

# %%
(new_df.groupby(['country_destination'])['gender'].value_counts()*100/new_df.groupby(['country_destination']).size()).round(1).unstack()
# Out:
# gender               -unknown-  FEMALE  MALE  OTHER
# country_destination
# AU                        26.5    38.4  34.9    0.2
# CA                        34.4    31.9  33.4    0.4
# DE                        26.8    33.7  39.2    0.3
# ES                        31.8    37.9  30.1    0.2
# FR                        34.1    39.1  26.6    0.3
# GB                        32.6    37.9  29.3    0.1
# IT                        36.7    38.5  24.7    0.2
# NL                        29.8    33.3  36.5    0.4
# PT                        31.8    35.9  31.8    0.5
# US                        32.2    36.4  31.2    0.2
# other                     34.4    31.3  34.1    0.2

# %% [markdown]
# ## 連續 vs 類別
# age 要clean

# %%
new_df['age'].describe()
# Out:
# count    68532.000000
# mean        47.872629
# std        146.042716
# min          2.000000
# 25%         28.000000
# 50%         33.000000
# 75%         42.000000
# max       2014.000000
# Name: age, dtype: float64

# %%
def age(x):
    if x > 1000:
        return 2015-x 
    else:
        return x

# %%
new_df['age_clean'] = new_df['age'].apply(age)

# %%
ax = new_df.groupby(['country_destination'])['age_clean'].mean().plot(kind='bar')
ax.set_ylabel('age')
# ax.set_xticklabels(train_df.groupby(['country_destination'])['age'].mean().keys())
# Out:
# Text(0, 0.5, 'age')

# %%
def age_bin(x):
    if 0<x<=30:
        return '0-30'
    elif 30<x<=60:
        return '30-60'
    elif x>60:
        return '60-100'
    else:
        return np.nan

# %%
new_df['age_bin'] = new_df['age_clean'].apply(age_bin)

# %%
(new_df.groupby(['age_bin'])['country_destination'].value_counts()*100/new_df.groupby(['age_bin']).size()).unstack().plot(kind='bar')

# %% [markdown]
# ### signup_flow
# signup_flow有影響

# %%
(new_df.groupby(['signup_flow'])['country_destination'].value_counts()*100/new_df.groupby(['signup_flow']).size()).round(1).unstack()
# Out:
# country_destination   AU    CA   DE   ES    FR    GB    IT   NL   PT     US  \
# signup_flow
# 0                    0.6   1.6  1.2  2.5   5.8   2.7   3.3  0.9  0.3   69.5
# 1                    0.6   3.0  0.6  3.0   2.4   1.8   3.6  2.4  NaN   71.6
# 2                    0.7   2.4  1.5  2.9   7.3   2.1   3.2  1.0  0.2   71.4
# 3                    0.5   1.8  1.4  3.1   6.4   2.7   3.6  0.9  0.2   69.4
# 5                    NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN  100.0
# 6                    0.6   1.2  NaN  4.9   7.9   1.8   1.8  2.4  1.2   66.5
# 8                    0.9   2.7  3.6  7.2   6.3   2.7  11.7  3.6  0.9   45.0
# 10                   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN  100.0
# 12                   0.6   1.0  0.8  2.0   3.1   2.1   1.8  0.7  0.1   76.6
# 15                   NaN   NaN  NaN  NaN   NaN  25.0   NaN  NaN  NaN   75.0
# 16                   NaN  50.0  NaN  NaN   NaN   NaN  50.0  NaN  NaN    NaN
# 20                   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN  100.0
# 21                   NaN   2.4  NaN  4.8  13.1   6.0   3.6  NaN  NaN   57.1
# 23                   0.3   1.7  0.8  2.2   2.3   0.6   1.4  0.5  0.2   74.5
# 24                   0.7   1.3  0.9  2.1   2.7   1.7   1.6  0.5  0.2   80.0
# 25                   0.5   1.1  0.8  1.7   4.0   2.1   3.0  0.8  0.3   73.2
#
# country_destination  other
# signup_flow
# 0                     11.6
# 1                     11.2
# 2                      7.5
# 3                     10.1
# 5                      NaN
# 6                     11.6
# 8                     15.3
# 10                     NaN
# 12                    11.3
# 15                     NaN
# 16                     NaN
# 20                     NaN
# 21                    13.1
# 23                    15.6
# 24                     8.4
# 25                    12.4

# %% [markdown]
# ## age_gender

# %%
age_gender.head(3)
# Out:
#   age_bucket country_destination gender  population_in_thousands    year
# 0       100+                  AU   male                      1.0  2015.0
# 1      95-99                  AU   male                      9.0  2015.0
# 2      90-94                  AU   male                     47.0  2015.0

# %% [markdown]
# ### gender

# %%
(age_gender.groupby(['gender', 'country_destination'])['population_in_thousands'].sum()*100/age_gender.groupby(['gender'])['population_in_thousands'].sum()).unstack()
# Out:
# country_destination        AU        CA         DE        ES        FR  \
# gender
# female               3.230460  4.853751  11.283238  6.413098  8.998487
# male                 3.306113  4.947084  11.270905  6.483028  8.749434
#
# country_destination        GB        IT        NL        PT         US
# gender
# female               8.690057  8.437509  2.279914  1.469075  44.344411
# male                 8.750823  8.263200  2.323365  1.428417  44.477632

# %%
(age_gender.groupby(['country_destination', 'gender'])['population_in_thousands'].sum()*100/age_gender.groupby(['country_destination'])['population_in_thousands'].sum()).unstack()
# Out:
# gender                  female       male
# country_destination
# AU                   50.261255  49.738745
# CA                   50.363804  49.636196
# DE                   50.867227  49.132773
# ES                   50.568820  49.431180
# FR                   51.541172  48.458828
# GB                   50.665727  49.334273
# IT                   51.361518  48.638482
# NL                   50.367996  49.632004
# PT                   51.541144  48.458856
# US                   50.764920  49.235080

# %% [markdown]
# ### age_bucket

# %%
(age_gender.groupby(['age_bucket', 'country_destination'])['population_in_thousands'].sum()*100/age_gender.groupby(['age_bucket'])['population_in_thousands'].sum()).unstack()
# Out:
# country_destination        AU        CA         DE        ES         FR  \
# age_bucket
# 0-4                  3.751227  4.758566   8.236339  5.772916   9.285748
# 10-14                3.432440  4.526087   8.739703  5.475334   9.182369
# 100+                 2.857143  4.571429   9.714286  6.857143  12.571429
# 15-19                3.471982  4.759268   9.343207  4.876923   9.070985
# 20-24                3.487186  5.125534   9.606579  4.949765   8.651780
# 25-29                3.658767  5.224115  10.661973  5.504914   8.637707
# 30-34                3.606842  5.168567  10.737895  7.011238   8.430425
# 35-39                3.381724  5.038727  10.263681  8.640538   7.825793
# 40-44                3.371975  4.775269  10.559284  8.086231   9.035998
# 45-49                3.029076  4.721965  13.269320  7.251658   8.510720
# 5-9                  3.599595  4.640158   8.171481  5.984415   9.195565
# 50-54                2.972744  5.264548  13.443365  6.526455   8.218429
# 55-59                2.972464  5.302565  12.231496  6.157686   8.313899
# 60-64                2.984319  5.148871  12.374790  5.874226   9.109540
# 65-69                3.052676  4.940308  10.830977  6.204838   9.857053
# 70-74                2.912655  4.660930  15.232534  6.556034   8.263334
# 75-79                2.683091  4.117449  18.363989  6.724603   9.032231
# 80-84                2.640361  4.332299  14.647854  8.207950  10.824893
# 85-89                2.709360  4.406130  13.729246  7.927386  11.339172
# 90-94                2.847910  4.463745  13.027671  7.432842  12.704504
# 95-99                3.139428  5.078486   8.125577  7.940905   9.418283
#
# country_destination         GB         IT        NL        PT         US
# age_bucket
# 0-4                   9.042678   6.663395  2.103492  1.084467  49.301173
# 10-14                 8.192879   6.760723  2.390872  1.311429  49.988164
# 100+                  9.142857  10.285714  1.142857  0.571429  42.285714
# 15-19                 8.413500   6.699426  2.293123  1.252682  49.818903
# 20-24                 8.719050   6.759543  2.237268  1.215199  49.248096
# 25-29                 9.084051   6.879571  2.143710  1.274072  46.931120
# 30-34                 8.886961   7.447116  2.065774  1.514213  45.130970
# 35-39                 8.344267   8.902950  2.073899  1.762814  43.765607
# 40-44                 8.639414   9.841367  2.369331  1.696156  41.624975
# 45-49                 8.965757   9.555761  2.481490  1.505861  40.708391
# 5-9                   9.228524   6.751889  2.172941  1.210067  49.045366
# 50-54                 8.537206   8.855984  2.418184  1.461850  42.301235
# 55-59                 8.011129   8.275030  2.375107  1.450432  44.910192
# 60-64                 7.985815   8.356552  2.410943  1.494462  44.260483
# 65-69                 9.406744   9.448633  2.735889  1.518484  42.004398
# 70-74                 9.202349   9.919415  2.479000  1.652667  39.121082
# 75-79                 9.044887  11.495950  2.282315  1.776072  34.479413
# 80-84                 9.115391  11.937240  2.277384  1.850009  34.166618
# 85-89                 8.821383  11.813538  2.089035  1.587302  35.577449
# 90-94                 9.190063  12.118764  1.898606  1.292668  35.023228
# 95-99                10.156971   9.325946  1.754386  1.108033  43.951985

# %% [markdown]
# ## Sessions
#
# * append：stacking vertically
# * pd.concat([]):
#     * stacking many horizontally or vertically
#     * simple inner/outer joins on indexes
# * .join：inner/outer/right/left join
# * pd.merge([df1, df2])：many joins on multiple columns
#
# Use
# 1. concat
# 2. merge

# %%
new_df.rename(columns={'id':'user_id'}, inplace=True)

# %%
sessions['action_detail'].nunique()
# Out:
# 155

# %%
# sessions['action_detail'].unique()

# %%
merge_df = pd.merge(sessions, new_df)

# %%
merge_df.groupby(['country_destination'])['action_detail'].apply(lambda x: x.value_counts().head(5)).unstack().plot(kind= 'bar')

# %%
merge_df[merge_df['action_detail']=='change_trip_characteristics']['country_destination'].value_counts()
# Out:
# US       99142
# other    21948
# FR       11727
# IT        7668
# ES        5061
# GB        4290
# CA        2552
# DE        1794
# NL        1587
# AU         829
# PT         453
# Name: country_destination, dtype: int64

# %% [markdown]
# ## 統計檢驗

# %%
from scipy import stats

# %% [markdown]
# ### 性別對國家影響

# %%
def chi2_test(contingency_table, alpha= 0.05):
    chi2, p, dof, expected = stats.chi2_contingency(contingency_table)
    
    print(f'chi^2 : {chi2}')
    print(f'degree of freedom : {dof}')
    
#     cramers_v = np.sqrt(chi2/(len()))
    if p < alpha:
        print(f'reject H0：\np value= {p}')
    else: 
        print(f'do not reject H0：\np value= {p}')

# %%
contingency = pd.crosstab(index= new_df['gender'], columns= new_df['country_destination'])

# %%
contingency.drop(contingency.index[[0,3]], inplace=True)

# %%
contingency
# Out:
# country_destination   AU   CA   DE   ES    FR   GB    IT   NL  PT     US  \
# gender
# FEMALE               207  455  358  853  1962  881  1091  254  78  22694
# MALE                 188  477  416  677  1335  682   699  278  69  19457
#
# country_destination  other
# gender
# FEMALE                3160
# MALE                  3443

# %%
chi2_test(contingency)
# Out:
# chi^2 : 214.26882956350897
# degree of freedom : 10
# reject H0：
# p value= 1.6903821526166418e-40

# %% [markdown]
# ### 語言對國家影響

# %%
contingency = pd.crosstab(index= new_df['language'], columns= new_df['country_destination'])

# %%
contingency.head(5)
# Out:
# country_destination  AU  CA  DE  ES  FR  GB  IT  NL  PT   US  other
# language
# ca                    0   0   0   0   0   0   0   0   0    2      0
# cs                    0   0   0   1   0   0   0   0   0    6      2
# da                    0   0   0   2   0   0   1   0   0   14      2
# de                    3   1  24   7  10   5   6   2   1  193     18
# el                    0   0   0   2   1   0   0   0   0    2      1

# %%
chi2_test(contingency)
# Out:
# chi^2 : 724.6838071905186
# degree of freedom : 220
# reject H0：
# p value= 3.766966078892133e-55

# %% [markdown]
# ### 年齡對國家影響

# %%
contingency = pd.crosstab(index= new_df['age_bin'], columns= new_df['country_destination'])

# %%
contingency
# Out:
# country_destination   AU   CA   DE   ES    FR    GB    IT   NL  PT     US  \
# age_bin
# 0-30                 149  341  305  695  1205   573   712  229  61  17769
# 30-60                262  672  486  915  2256  1049  1168  326  89  28124
# 60-100                25   64   60   96   252   152   156   47   8   2710
#
# country_destination  other
# age_bin
# 0-30                  2642
# 30-60                 4459
# 60-100                 475

# %%
chi2_test(contingency)
# Out:
# chi^2 : 116.04397722426503
# degree of freedom : 20
# reject H0：
# p value= 1.533175387896118e-15

# %% [markdown]
# ### Signup_method 對國家影響

# %%
contingency = pd.crosstab(index= new_df['signup_method'], columns= new_df['country_destination'])

# %%
contingency.drop(contingency.index[[2]], inplace= True)

# %%
contingency
# Out:
# country_destination   AU    CA   DE    ES    FR    GB    IT   NL   PT     US  \
# signup_method
# basic                393  1105  737  1601  3767  1727  2147  560  154  45430
# facebook             146   322  323   646  1253   597   686  202   62  16867
#
# country_destination  other
# signup_method
# basic                 7430
# facebook              2652

# %%
chi2_test(contingency)
# Out:
# chi^2 : 48.529098330938574
# degree of freedom : 10
# reject H0：
# p value= 4.967768526593509e-07

# %% [markdown]
# ### 年份對國家影響

# %%
new_df['year'] = new_df['date_first_booking'].apply(lambda x: x.split('-')[0])
new_df['month'] = new_df['date_first_booking'].apply(lambda x: x.split('-')[1])

# %%
contingency= pd.crosstab(index= new_df['year'], columns= new_df['country_destination'])

# %%
contingency.drop(contingency.index[[0,-1]], inplace=True)

# %%
contingency
# Out:
# country_destination   AU   CA   DE   ES    FR   GB    IT   NL  PT     US  \
# year
# 2011                  32  116   89  174   420  147   177   60  17   4023
# 2012                  95  269  264  441  1026  483   546  142  33  11219
# 2013                 216  476  388  771  1784  828   961  269  74  22011
# 2014                 179  509  298  806  1607  802  1090  269  87  22632
#
# country_destination  other
# year
# 2011                   483
# 2012                  1723
# 2013                  3481
# 2014                  4140

# %%
chi2_test(contingency)
# Out:
# chi^2 : 273.93577447316915
# degree of freedom : 30
# reject H0：
# p value= 3.4220695184701245e-41

# %%
contingency= pd.crosstab(index= new_df['affiliate_channel'], columns= new_df['country_destination'])

# %%
contingency.drop(contingency.index[[0,1,3,4]],inplace=True)

# %%
contingency
# Out:
# country_destination   AU   CA   DE    ES    FR    GB    IT   NL   PT     US  \
# affiliate_channel
# direct               363  945  699  1536  3294  1579  1858  503  144  41725
# sem-brand             65  154  137   278   669   329   463  103   37   7725
# sem-non-brand         59  147  112   180   533   193   242   80   17   4552
# seo                   17   58   46   118   233    99   121   34    8   2729
#
# country_destination  other
# affiliate_channel
# direct                6752
# sem-brand             1134
# sem-non-brand         1035
# seo                    492

# %%
chi2_test(contingency)
# Out:
# chi^2 : 232.08907032821926
# degree of freedom : 30
# reject H0：
# p value= 4.1889007153363664e-33

# %% [markdown]
# ----

# %% [markdown]
# ## Model

# %%
from sklearn.feature_selection import RFE, RFECV, SelectKBest, chi2
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import preprocessing
import copy 
import xgboost as xgb

# %%
new_df.head(3)
# Out:
#       user_id date_account_created  timestamp_first_active date_first_booking  \
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination  age_clean age_bin  year month
# 2            IE                  US       56.0   30-60  2010    08
# 3       Firefox               other       42.0   30-60  2012    09
# 4        Chrome                  US       41.0   30-60  2010    02

# %%
test_df.head(3)
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
#
#   first_device_type  first_browser
# 0            iPhone  Mobile Safari
# 1            iPhone  Mobile Safari
# 2   Windows Desktop         Chrome

# %% [markdown]
# ### Preprocessing
# * XGBoost Only allows int, float, or boolean data types
# * Converting it with to_numeric()

# %%
X = new_df.drop('country_destination', axis= 1).copy()

# %%
X.drop(['user_id', 'date_first_booking', 'age','date_account_created', 'timestamp_first_active'], axis= 1, inplace= True)

# %%
X.fillna(0, inplace=True)

# %%
X['year'] = pd.to_numeric(X['year'])
X['month'] = pd.to_numeric(X['month'])

# %%
X.head(3)
# Out:
#       gender signup_method  signup_flow language affiliate_channel  \
# 2     FEMALE         basic            3       en            direct
# 3     FEMALE      facebook            0       en            direct
# 4  -unknown-         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser  age_clean age_bin  year  month
# 2            IE       56.0   30-60  2010      8
# 3       Firefox       42.0   30-60  2012      9
# 4        Chrome       41.0   30-60  2010      2

# %%
y = new_df['country_destination'].copy()

# %%
assert len(X) == len(y), 'length is not matched'

# %% [markdown]
# #### Encoding

# %%
obj_cols = X.select_dtypes(include=['object']).columns

# %%
X_encoded = pd.get_dummies(X, columns=obj_cols)

# %%
# le = preprocessing.LabelEncoder()
# y = le.fit_transform(y)

# %% [markdown]
# #### split
# param：stratify = y

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state= 42, stratify= y)

# %%
assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)

# %%
print(f'training size: {len(X_train)/(len(X_train)+len(X_test))}\ntesting size: {len(X_test)/(len(X_train)+len(X_test))}')
# Out:
# training size: 0.75
# testing size: 0.25

# %% [markdown]
# #### training
# * subsample：for each tree, how many percent of data used
# * colsample_bytree：for each tree, how many percent of columns (reduce overfitting)

# %%
clf = xgb.XGBClassifier(objective='multi:softprob', 
                        missing= None, 
                        subsample= 0.5,
                        colsample_bytree= 0.5,
#                         scale_pos_weight= 3,
                        seed=42)

# %%
# clf.fit(X_train,
#        y_train,
#        verbose=True,
#        early_stopping_rounds=10,
#        eval_metric='mlogloss',
#        eval_set=[(X_test, y_test)])

# %%
# plot_confusion_matrix(clf,
#                       X_test,
#                       y_test,
#                       values_format= 'd')

# %% [markdown]
# #### Imbalance Learn

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
smote = SMOTE()

# %%
X_train_smote, y_train_smote= smote.fit_sample(X_train, y_train)

# %%
print(f'value counts before SMOTE: {Counter(y_train)}')
print(f'value counts after SMOTE: {Counter(y_train_smote)}')
# Out:
# value counts before SMOTE: Counter({'US': 46782, 'other': 7571, 'FR': 3767, 'IT': 2126, 'GB': 1743, 'ES': 1687, 'CA': 1071, 'DE': 796, 'NL': 571, 'AU': 404, 'PT': 163})
# value counts after SMOTE: Counter({'US': 46782, 'IT': 46782, 'other': 46782, 'GB': 46782, 'DE': 46782, 'ES': 46782, 'FR': 46782, 'CA': 46782, 'PT': 46782, 'AU': 46782, 'NL': 46782})

# %%
clf.fit(X_train_smote,
       y_train_smote,
       verbose=True,
       early_stopping_rounds=5,
       eval_metric='mlogloss',
       eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-mlogloss:2.31135
# [1]	validation_0-mlogloss:2.25735
# [2]	validation_0-mlogloss:2.14940
# [3]	validation_0-mlogloss:2.07045
# [4]	validation_0-mlogloss:2.01559
# [5]	validation_0-mlogloss:1.97021
# [6]	validation_0-mlogloss:1.91514
# [7]	validation_0-mlogloss:1.89582
# [8]	validation_0-mlogloss:1.87234
# [9]	validation_0-mlogloss:1.84883
# [10]	validation_0-mlogloss:1.81736
# [11]	validation_0-mlogloss:1.79266
# [12]	validation_0-mlogloss:1.76648
# [13]	validation_0-mlogloss:1.74670
# [14]	validation_0-mlogloss:1.70861
# [15]	validation_0-mlogloss:1.69433
# [16]	validation_0-mlogloss:1.67817
# [17]	validation_0-mlogloss:1.65585
# [18]	validation_0-mlogloss:1.64806
# [19]	validation_0-mlogloss:1.63454
# [20]	validation_0-mlogloss:1.62543
# [21]	validation_0-mlogloss:1.61253
# [22]	validation_0-mlogloss:1.60641
# [23]	validation_0-mlogloss:1.60038
# [24]	validation_0-mlogloss:1.58723
# [25]	validation_0-mlogloss:1.58120
# [26]	validation_0-mlogloss:1.57350
# [27]	validation_0-mlogloss:1.56698
# [28]	validation_0-mlogloss:1.55658
# [29]	validation_0-mlogloss:1.54657
# [30]	validation_0-mlogloss:1.54277
# [31]	validation_0-mlogloss:1.53315
# [32]	validation_0-mlogloss:1.52329
# [33]	validation_0-mlogloss:1.51890
# [34]	validation_0-mlogloss:1.51595
# [35]	validation_0-mlogloss:1.50970
# [36]	validation_0-mlogloss:1.50581
# [37]	validation_0-mlogloss:1.50420
# [38]	validation_0-mlogloss:1.50200
# [39]	validation_0-mlogloss:1.49613
# [40]	validation_0-mlogloss:1.48636
# [41]	validation_0-mlogloss:1.48358
# [42]	validation_0-mlogloss:1.48141
# [43]	validation_0-mlogloss:1.47794
# [44]	validation_0-mlogloss:1.47354
# [45]	validation_0-mlogloss:1.46983
# [46]	validation_0-mlogloss:1.46809
# [47]	validation_0-mlogloss:1.46565
# [48]	validation_0-mlogloss:1.46173
# [49]	validation_0-mlogloss:1.46104
# [50]	validation_0-mlogloss:1.45904
# [51]	validation_0-mlogloss:1.45746
# [52]	validation_0-mlogloss:1.45734
# [53]	validation_0-mlogloss:1.45320
# [54]	validation_0-mlogloss:1.45212
# [55]	validation_0-mlogloss:1.45006
# [56]	validation_0-mlogloss:1.44681
# [57]	validation_0-mlogloss:1.44189
# [58]	validation_0-mlogloss:1.44073
# [59]	validation_0-mlogloss:1.43987
# [60]	validation_0-mlogloss:1.43761
# [61]	validation_0-mlogloss:1.43495
# [62]	validation_0-mlogloss:1.43433
# [63]	validation_0-mlogloss:1.43263
# [64]	validation_0-mlogloss:1.42986
# [65]	validation_0-mlogloss:1.42986
# [66]	validation_0-mlogloss:1.42803
# [67]	validation_0-mlogloss:1.42745
# [68]	validation_0-mlogloss:1.42406
# [69]	validation_0-mlogloss:1.42306
# [70]	validation_0-mlogloss:1.42289
# [71]	validation_0-mlogloss:1.42244
# [72]	validation_0-mlogloss:1.42110
# [73]	validation_0-mlogloss:1.42085
# [74]	validation_0-mlogloss:1.41934
# [75]	validation_0-mlogloss:1.41835
# [76]	validation_0-mlogloss:1.41855
# [77]	validation_0-mlogloss:1.41892
# [78]	validation_0-mlogloss:1.41880
# [79]	validation_0-mlogloss:1.41710
# [80]	validation_0-mlogloss:1.41748
# [81]	validation_0-mlogloss:1.41690
# [82]	validation_0-mlogloss:1.41550
# [83]	validation_0-mlogloss:1.41452
# [84]	validation_0-mlogloss:1.41282
# [85]	validation_0-mlogloss:1.41311
# [86]	validation_0-mlogloss:1.41381
# [87]	validation_0-mlogloss:1.41371
# [88]	validation_0-mlogloss:1.41345
# [89]	validation_0-mlogloss:1.41373
# [90]	validation_0-mlogloss:1.41403
# [91]	validation_0-mlogloss:1.41395
# [92]	validation_0-mlogloss:1.41280
# [93]	validation_0-mlogloss:1.41319
# [94]	validation_0-mlogloss:1.41221
# [95]	validation_0-mlogloss:1.41175
# [96]	validation_0-mlogloss:1.41146
# [97]	validation_0-mlogloss:1.41186
# [98]	validation_0-mlogloss:1.41223
# [99]	validation_0-mlogloss:1.41051
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=None, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1,
#               objective='multi:softprob', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, seed=42, subsample=0.5,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
plot_confusion_matrix(clf,
                      X_test,
                      y_test,
                      values_format= 'd')

# %% [markdown]
# #### Check Underfitting

# %%
y_pred = clf.predict(X_train_smote)

# %%
print(classification_report(y_true= y_train_smote, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AU       0.62      0.83      0.71     46782
#           CA       0.53      0.51      0.52     46782
#           DE       0.56      0.59      0.58     46782
#           ES       0.54      0.43      0.48     46782
#           FR       0.54      0.33      0.41     46782
#           GB       0.55      0.34      0.42     46782
#           IT       0.48      0.39      0.43     46782
#           NL       0.55      0.71      0.62     46782
#           PT       0.64      0.91      0.75     46782
#           US       0.57      0.86      0.68     46782
#        other       0.51      0.31      0.39     46782
#
#     accuracy                           0.56    514602
#    macro avg       0.55      0.56      0.54    514602
# weighted avg       0.55      0.56      0.54    514602

# %% [markdown]
# #### Check overfitting

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_true= y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AU       0.00      0.00      0.00       135
#           CA       0.02      0.01      0.01       357
#           DE       0.02      0.01      0.01       265
#           ES       0.04      0.02      0.02       562
#           FR       0.09      0.04      0.06      1256
#           GB       0.03      0.01      0.02       581
#           IT       0.05      0.05      0.05       709
#           NL       0.00      0.00      0.00       191
#           PT       0.02      0.02      0.02        54
#           US       0.71      0.85      0.77     15594
#        other       0.14      0.07      0.10      2523
#
#     accuracy                           0.61     22227
#    macro avg       0.10      0.10      0.10     22227
# weighted avg       0.52      0.61      0.56     22227
